# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

#Data visualization
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Reading the csv file data

# %%
df = pd.read_csv('menu.csv')
df.isnull().sum()
# Out:
# Category                         0
# Item                             0
# Serving Size                     0
# Calories                         0
# Calories from Fat                0
# Total Fat                        0
# Total Fat (% Daily Value)        0
# Saturated Fat                    0
# Saturated Fat (% Daily Value)    0
# Trans Fat                        0
# Cholesterol                      0
# Cholesterol (% Daily Value)      0
# Sodium                           0
# Sodium (% Daily Value)           0
# Carbohydrates                    0
# Carbohydrates (% Daily Value)    0
# Dietary Fiber                    0
# Dietary Fiber (% Daily Value)    0
# Sugars                           0
# Protein                          0
# Vitamin A (% Daily Value)        0
# Vitamin C (% Daily Value)        0
# Calcium (% Daily Value)          0
# Iron (% Daily Value)             0
# dtype: int64

# %%
df.head(5)
# Out:
#     Category                              Item    Serving Size  Calories  \
# 0  Breakfast                      Egg McMuffin  4.8 oz (136 g)       300
# 1  Breakfast                 Egg White Delight  4.8 oz (135 g)       250
# 2  Breakfast                  Sausage McMuffin  3.9 oz (111 g)       370
# 3  Breakfast         Sausage McMuffin with Egg  5.7 oz (161 g)       450
# 4  Breakfast  Sausage McMuffin with Egg Whites  5.7 oz (161 g)       400
#
#    Calories from Fat  Total Fat  Total Fat (% Daily Value)  Saturated Fat  \
# 0                120       13.0                         20            5.0
# 1                 70        8.0                         12            3.0
# 2                200       23.0                         35            8.0
# 3                250       28.0                         43           10.0
# 4                210       23.0                         35            8.0
#
#    Saturated Fat (% Daily Value)  Trans Fat  ...  Carbohydrates  \
# 0                             25        0.0  ...             31
# 1                             15        0.0  ...             30
# 2                             42        0.0  ...             29
# 3                             52        0.0  ...             30
# 4                             42        0.0  ...             30
#
#    Carbohydrates (% Daily Value)  Dietary Fiber  \
# 0                             10              4
# 1                             10              4
# 2                             10              4
# 3                             10              4
# 4                             10              4
#
#    Dietary Fiber (% Daily Value)  Sugars  Protein  Vitamin A (% Daily Value)  \
# 0                             17       3       17                         10
# 1                             17       3       18                          6
# 2                             17       2       14                          8
# 3                             17       2       21                         15
# 4                             17       2       21                          6
#
#    Vitamin C (% Daily Value)  Calcium (% Daily Value)  Iron (% Daily Value)
# 0                          0                       25                    15
# 1                          0                       25                     8
# 2                          0                       25                    10
# 3                          0                       30                    15
# 4                          0                       25                    10
#
# [5 rows x 24 columns]

# %% [markdown]
#  ### Okay data looks cleaner than what I have expected and from the dataframe head, it can be inferred that the data  consist of a column "item" which contains food item names and other columns describe its nutrition value

# %% [markdown]
# *   ### *Vitamin A* Swarmplot

# %%
plot = sns.swarmplot(x="Category", y="Vitamin A (% Daily Value)", data=df)
plt.setp(plot.get_xticklabels(),rotation=70)
plt.title("Vitamin A (% Daily Value)")
plt.show()
# Out:
# C:\Users\DELL\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\seaborn\categorical.py:3398: UserWarning: 28.6% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\DELL\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\seaborn\categorical.py:3398: UserWarning: 13.3% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\DELL\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\seaborn\categorical.py:3398: UserWarning: 7.4% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\DELL\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\seaborn\categorical.py:3398: UserWarning: 23.1% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\DELL\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\seaborn\categorical.py:3398: UserWarning: 66.7% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\DELL\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\seaborn\categorical.py:3398: UserWarning: 62.1% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# Well, it's a known fact that salads(vegetable) contain vitamin A in abundant amount. Let's find out for which items we are getting maximum and minimum value for vitamin A

# %%
df.at[df["Vitamin A (% Daily Value)"].idxmax(),'Item']
# Out:
# 'Premium Bacon Ranch Salad (without Chicken)'

# %%
df.at[df["Vitamin A (% Daily Value)"].idxmin(),'Item']
# Out:
# 'Sausage Biscuit (Regular Biscuit)'

# %% [markdown]
# so, its 'Premium Bacon Ranch Salad(without Chicken)' and 'Sausage Biscuit (Regular Biscuit)' respectively.

# %% [markdown]
# *   ### *Vitamin C* Swarmplot

# %%
plot = sns.swarmplot(x="Category", y="Vitamin C (% Daily Value)", data=df)
plt.setp(plot.get_xticklabels(),rotation=70)
plt.title("Vitamin C (% Daily Value)")
plt.show()
# Out:
# C:\Users\DELL\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\seaborn\categorical.py:3398: UserWarning: 59.5% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\DELL\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\seaborn\categorical.py:3398: UserWarning: 6.7% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\DELL\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\seaborn\categorical.py:3398: UserWarning: 59.3% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\DELL\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\seaborn\categorical.py:3398: UserWarning: 92.6% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\DELL\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\seaborn\categorical.py:3398: UserWarning: 53.6% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# "Beverages" has maximum value for Vitamin C followed by "snacks and sides". We can see an outlier in the beverages section. Let's find it out.

# %%
df.at[df["Vitamin C (% Daily Value)"].idxmax(),'Item']
# Out:
# 'Minute Maid Orange Juice (Large)'

# %%
df.at[df["Vitamin C (% Daily Value)"].idxmin(),'Item']
# Out:
# 'Egg McMuffin'

# %% [markdown]
# 'Minute Maid Orange Juice (Large)" contain vitamin C in copious amount.

# %% [markdown]
# *   ### *Calcium* Swarmplot

# %%
plot = sns.swarmplot(x="Category", y="Calcium (% Daily Value)", data=df)
plt.setp(plot.get_xticklabels(),rotation=70)
plt.title("Calcium (% Daily Value)")
plt.show()
# Out:
# C:\Users\DELL\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\seaborn\categorical.py:3398: UserWarning: 7.1% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\DELL\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\seaborn\categorical.py:3398: UserWarning: 7.4% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\DELL\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\seaborn\categorical.py:3398: UserWarning: 51.9% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\DELL\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\seaborn\categorical.py:3398: UserWarning: 36.8% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
df.at[df["Calcium (% Daily Value)"].idxmax(),'Item']
# Out:
# 'Strawberry Shake (Large)'

# %%
df.at[df["Calcium (% Daily Value)"].idxmin(),'Item']
# Out:
# 'Hash Brown'

# %% [markdown]
# So, "Smoothies and shakes" contain Calcium in ample amount, even more than "coffee and tea" section(Interesting).

# %% [markdown]
# *   ### *Iron* Swarmplot

# %%
plot = sns.swarmplot(x="Category", y="Iron (% Daily Value)", data=df)
plt.setp(plot.get_xticklabels(),rotation=70)
plt.title("Iron (% Daily Value)")
plt.show()
# Out:
# C:\Users\DELL\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\seaborn\categorical.py:3398: UserWarning: 31.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\DELL\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\seaborn\categorical.py:3398: UserWarning: 25.9% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\DELL\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\seaborn\categorical.py:3398: UserWarning: 70.4% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\DELL\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\seaborn\categorical.py:3398: UserWarning: 64.2% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
df.at[df["Iron (% Daily Value)"].idxmax(),'Item']
# Out:
# 'Big Breakfast with Hotcakes (Regular Biscuit)'

# %%
df.at[df["Iron (% Daily Value)"].idxmin(),'Item']
# Out:
# 'Apple Slices'

# %% [markdown]
# If you are looking for iron in your food then you have to opt for "Breakfast section" to be precise go for "Big Breakfast with Hotcakes (Regular Biscuit)"

# %% [markdown]
# *   ### *Protein* Swarmplot

# %%
plot = sns.swarmplot(x="Category", y="Protein", data=df)
plt.setp(plot.get_xticklabels(),rotation=70)
plt.title("Protein")
plt.show()
# Out:
# C:\Users\DELL\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\seaborn\categorical.py:3398: UserWarning: 44.4% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\DELL\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\seaborn\categorical.py:3398: UserWarning: 47.4% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
df.at[df["Protein"].idxmax(),'Item']
# Out:
# 'Chicken McNuggets (40 piece)'

# %%
df.at[df["Protein"].idxmin(),'Item']
# Out:
# 'Apple Slices'

# %% [markdown]
# Now, this is a section which intrigued most of us. If you are looking for protein in your food go for "chicken & fish" or "Beef and pork" section. we also have an outlier item "Chicken McNuggets (40 pieces) it approximately has twice amount of protein compares to other"

# %% [markdown]
# *   ### *Trans Fat* Swarmplot

# %%
plot = sns.swarmplot(x="Category", y="Trans Fat", data=df)
plt.setp(plot.get_xticklabels(),rotation=70)
plt.title("Trans Fat")
plt.show()
# Out:
# C:\Users\DELL\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\seaborn\categorical.py:3398: UserWarning: 71.4% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\DELL\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\seaborn\categorical.py:3398: UserWarning: 51.9% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\DELL\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\seaborn\categorical.py:3398: UserWarning: 46.2% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\DELL\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\seaborn\categorical.py:3398: UserWarning: 74.1% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\DELL\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\seaborn\categorical.py:3398: UserWarning: 75.8% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\DELL\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\seaborn\categorical.py:3398: UserWarning: 42.9% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
df.at[df["Trans Fat"].idxmax(),'Item']
# Out:
# 'Double Quarter Pounder with Cheese'

# %%
df.at[df["Trans Fat"].idxmin(),'Item']
# Out:
# 'Egg McMuffin'

# %% [markdown]
# An interesting observation that I can see from the plot is that 4 sections ("salads", "snacks and slides", "Desserts", "Beverages") having a value very near to zero.

# %% [markdown]
# *   ### *Sugars* Swarmplot

# %%
plot = sns.swarmplot(x="Category", y="Sugars", data=df)
plt.setp(plot.get_xticklabels(),rotation=70)
plt.title("Sugars")
plt.show()
# Out:
# C:\Users\DELL\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\seaborn\categorical.py:3398: UserWarning: 42.9% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\DELL\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\seaborn\categorical.py:3398: UserWarning: 7.4% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\DELL\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\seaborn\categorical.py:3398: UserWarning: 7.7% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\DELL\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\seaborn\categorical.py:3398: UserWarning: 6.3% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\DELL\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\seaborn\categorical.py:3398: UserWarning: 8.4% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
df.at[df["Sugars"].idxmax(),'Item']
# Out:
# 'McFlurry with M&M’s Candies (Medium)'

# %%
df.at[df["Sugars"].idxmin(),'Item']
# Out:
# 'Hash Brown'

# %% [markdown]
# No doubts, why most of the people love 'McFlurry with M&M’s Candies (Medium)'

# %% [markdown]
# *   ### *Cholesterol* Swarmplot

# %%
plot = sns.swarmplot(x="Category", y="Cholesterol", data=df)
plt.setp(plot.get_xticklabels(),rotation=70)
plt.title("Cholesterol")
plt.show()
# Out:
# C:\Users\DELL\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\seaborn\categorical.py:3398: UserWarning: 16.7% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\DELL\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\seaborn\categorical.py:3398: UserWarning: 74.1% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\DELL\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\seaborn\categorical.py:3398: UserWarning: 62.1% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\DELL\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\seaborn\categorical.py:3398: UserWarning: 7.1% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
df.at[df["Cholesterol"].idxmax(),'Item']
# Out:
# 'Big Breakfast with Hotcakes (Regular Biscuit)'

# %%
df.at[df["Cholesterol"].idxmin(),'Item']
# Out:
# 'Hash Brown'

# %% [markdown]
# Well 'hash brown' seems to be a good food option it has the least value for sugar and cholesterol columns.

# %% [markdown]
# *   ### *Calories* Swarmplot

# %%
plot = sns.swarmplot(x="Category", y="Calories", data=df)
plt.setp(plot.get_xticklabels(),rotation=70)
plt.title("Calories")
plt.show()
# Out:
# C:\Users\DELL\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\seaborn\categorical.py:3398: UserWarning: 7.4% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\DELL\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\seaborn\categorical.py:3398: UserWarning: 22.1% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
df.at[df["Calories"].idxmax(),'Item']
# Out:
# 'Chicken McNuggets (40 piece)'

# %%
df.at[df["Calories"].idxmin(),'Item']
# Out:
# 'Diet Coke (Small)'

# %% [markdown]
# Chicken McNuggets is containg more than the twice amount of calories when compares to other.

# %%
df_numeric = df.select_dtypes(include=['float64', 'int64'])

# Calculate correlation matrix
corr = df_numeric.corr()

# Plot the correlation heatmap
plt.figure(figsize=(10, 10))
sns.heatmap(corr, mask=np.zeros_like(corr, dtype=bool), cmap=sns.diverging_palette(220, 10, as_cmap=True),
            square=True)
plt.title("McD Correlation Heatmap")
plt.show()

# %% [markdown]
# Well the correlation matrix confirms the finding that we have discovered above.

# %% [markdown]
# ## Conclusion

# %% [markdown]
# ### What to avoid?
# *  Chicken McNuggets:- Although its provide you ample amount of protein but its also contain huge amount of calories (more than 1750).
# *  Big Breakfast with Hotcakes (Regular Biscuit):- contain excess amount of cholesterol.
# *  Double Quarter Pounder with Cheese :- If you are on diet than avoid this item, it contain a bumper amount of trans fat
#
# ### Safe options
# * Hash Brown
# * Diet Coke (Small)
